# %% [markdown]
# <a href="https://colab.research.google.com/github/andres-merino/MatematicaIII-05-N0051/blob/main/10Laboratorios/00-Formato.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table style="border: none; border-collapse: collapse;">
#     <tr>
#         <td style="width: 20%; vertical-align: middle; padding-right: 10px;">
#             <img src="https://i.imgur.com/X5m8yDo.png" width="120">
#         </td>
#         <td style="width: 2px; text-align: center;">
#             <font color="#1957d1" size="7">|</font><br>
#             <font color="#1957d1" size="7">|</font>
#         </td>
#         <td>
#             <p style="font-variant: small-caps;"><font color="#1957d1" size="5">
#                 <b>Facultad de Ciencias Exactas, Naturales y Ambientales</b>
#             </font> </p>
#             <p style="font-variant: small-caps;"><font color="#1957d1" size="4">
#                 Matemática III &bull; Cuaderno de trabajo
#             </font></p>
#             <p style="font-style: oblique;"><font color="#1957d1" size="3">
#                 Andrés Merino &bull; Periodo 2026-01
#             </font></p>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ---
# ## <font color='1957d1'> Introducción </font>
#
# Este notebook está diseñado como una guía para [...]. Los resultados de aprendizaje de esta actividad son:
#
# - ...
# - ...

# %% [markdown]
# Los paquetes necesarios son:

# %%
# Paquetes necesarios
import sympy as sp  # Para cálculo simbólico
import matplotlib.pyplot as plt  # Para visualización

# %% [markdown]
# ---
# ## <font color='1957d1'> [...] </font>
#
# [Explicar los comandos y dar ejemplos]

# %% [markdown]
# Utilicemos datos ficticios:

# %%
# [...]

# %% [markdown]
# ---
#
# <div style="background-color: #edf1f8; border-color: #1957d1; border-left: 5px solid #1957d1; padding: 0.5em;">
# <strong>Ejercicio:</strong><br>
# [...]
# </div>
#
# ---
